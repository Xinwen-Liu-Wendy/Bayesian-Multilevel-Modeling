# %%
using JSON
using DataFrames
using StatsPlots
using Turing
using LinearAlgebra
using Random
using Plots

# %% [markdown]
# ### Multi-level model using football match simulation as an example

# %%
## First, import the data and do some data wrangling

england_league = JSON.parsefile("./data/matches_England.json")

matches_df = DataFrame(home = [], away = [], score_home = [], score_away = [])
# Out:
# 0×4 DataFrame
#  Row │ home  away  score_home  score_away
#      │ Any   Any   Any         Any
# ─────┴────────────────────────────────────

# %%
# example entry for each game in england_league:  "label" => "Burnley - AFC Bournemouth, 1 - 2"
matches = []
for match in england_league
    push!(matches, split(match["label"], ",")) # "Burnley - AFC Bournemouth" # "1 - 2"
end

for match in matches
    home, away = split(match[1], " - ")  # "Burnley" # "AFC Bournemouth" 
    score_home, score_away = split(match[2], " - ") # "1" # "2"
    push!(matches_df,[home, away, parse(Int,score_home), parse(Int,score_away)])
end

println(size(matches_df))

teams = unique(collect(matches_df[:,1]))
# Out:
# (380, 4)
# 20-element Vector{Any}:
#  "Burnley"
#  "Crystal Palace"
#  "Huddersfield Town"
#  "Liverpool"
#  "Manchester United"
#  "Newcastle United"
#  "Southampton"
#  "Swansea City"
#  "Tottenham Hotspur"
#  "West Ham United"
#  "Manchester City"
#  "Leicester City"
#  "Chelsea"
#  "Arsenal"
#  "Everton"
#  "AFC Bournemouth"
#  "Watford"
#  "West Bromwich Albion"
#  "Stoke City"
#  "Brighton & Hove Albion"

# %%
matches_df[]
# Out:
# 380×4 DataFrame
#  Row │ home                    away                    score_home  score_away
#      │ Any                     Any                     Any         Any
# ─────┼────────────────────────────────────────────────────────────────────────
#    1 │ Burnley                 AFC Bournemouth         1           2
#    2 │ Crystal Palace          West Bromwich Albion    2           0
#    3 │ Huddersfield Town       Arsenal                 0           1
#    4 │ Liverpool               Brighton & Hove Albion  4           0
#    5 │ Manchester United       Watford                 1           0
#    6 │ Newcastle United        Chelsea                 3           0
#    7 │ Southampton             Manchester City         0           1
#    8 │ Swansea City            Stoke City              1           2
#   ⋮  │           ⋮                       ⋮                 ⋮           ⋮
#  374 │ Chelsea                 Burnley                 2           3
#  375 │ Crystal Palace          Huddersfield Town       0           3
#  376 │ Everton                 Stoke City              1           0
#  377 │ Southampton             Swansea City            0           0
#  378 │ West Bromwich Albion    AFC Bournemouth         1           0
#  379 │ Watford                 Liverpool               3           3
#  380 │ Arsenal                 Leicester City          4           3
#                                                               365 rows omitted

# %%
## Now, our model

@model function football_matches(home_teams, away_teams, score_home, score_away, teams)

    # Hyper priors
    μatt ~ Normal(0, 0.1)
    μdef ~ Normal(0, 0.1)
    σatt ~ Exponential(1)
    σdef ~ Exponential(1)
    home ~ Normal(0, 1)
        
    # Team-specific effects
    
    att = zeros(length(teams))
    def = zeros(length(teams))
    
    for i in 1:length(teams)
        att[i] ~ Normal(μatt, σatt)
        def[i] ~ Normal(μdef, σdef)
    end

    #att ~ filldist(Normal(μatt, σatt), length(teams))  # more compact than for-loops
    #def ~ filldist(Normal(μdef, σdef), length(teams))
    
    offset = mean(att) + mean(def)
    
    # the number of matches
    n_matches = length(home_teams)

    # scoring rates θ
    θ_home = Vector{Real}(undef, n_matches)     # or just θ_home = zeros(n_matches)
    θ_away = Vector{Real}(undef, n_matches)     # or just θ_away = zeros(n_matches)
        
    # Modeling score-rate and scores for each match
    for i in 1:n_matches
        # scoring rate
        home_team_idx = findfirst(isequal(home_teams[i]), teams)
        away_team_idx = findfirst(isequal(away_teams[i]), teams)

        θ_home[i] = home + att[home_team_idx] + def[away_team_idx] - offset
        θ_away[i] = att[away_team_idx] + def[home_team_idx] - offset

        # scores
        score_home[i] ~ Poisson(exp(θ_home[i]))  # To ensure positive λ for Poisson distribution
        score_away[i] ~ Poisson(exp(θ_away[i]))
    end
end
# Out:
# football_matches (generic function with 2 methods)

# %%
model = football_matches(matches_df[:,1], matches_df[:,2], matches_df[:,3], matches_df[:,4], teams);

posterior = sample(model, NUTS(), 3000)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.00625
# └ @ Turing.Inference /Users/xinwenliu/.julia/packages/Turing/vX5F9/src/mcmc/hmc.jl:213
# Sampling   0%|▎                                         |  ETA: 0:06:48
# Sampling   1%|▍                                         |  ETA: 0:05:29
# Sampling   2%|▋                                         |  ETA: 0:04:56
# Sampling   2%|▉                                         |  ETA: 0:04:25
# Sampling   2%|█                                         |  ETA: 0:04:21
# Sampling   3%|█▎                                        |  ETA: 0:04:09
# Sampling   4%|█▌                                        |  ETA: 0:03:53
# Sampling   4%|█▋                                        |  ETA: 0:03:41
# Sampling   4%|█▉                                        |  ETA: 0:03:35
# Sampling   5%|██▏                                       |  ETA: 0:03:31
# Sampling   6%|██▎                                       |  ETA: 0:03:22
# Sampling   6%|██▌                                       |  ETA: 0:03:17
# Sampling   6%|██▊                                       |  ETA: 0:03:12
# Sampling   7%|███                                       |  ETA: 0:03:09
# Sampling   8%|███▏                                      |  ETA: 0:03:05
# Sampling   8%|███▍                                      |  ETA: 0:03:05
# Sampling   8%|███▋                                      |  ETA: 0:03:04
# Sampling   9%|███▊                                      |  ETA: 0:03:04
# Sampling  10%|████                                      |  ETA: 0:03:00
# Sampling  10%|████▎                                     |  ETA: 0:03:04
# Sampling  10%|████▍                                     |  ETA: 0:03:00
# Sampling  11%|████▋                                     |  ETA: 0:03:01
# Sampling  12%|████▉                                     |  ETA: 0:03:00
# Sampling  12%|█████                                     |  ETA: 0:02:58
# Sampling  12%|█████▎                                    |  ETA: 0:02:57
# Sampling  13%|█████▌                                    |  ETA: 0:02:55
# Sampling  14%|█████▋                                    |  ETA: 0:02:52
# Sampling  14%|█████▉                                    |  ETA: 0:02:51
# Sampling  14%|██████▏                                   |  ETA: 0:02:47
# Sampling  15%|██████▎                                   |  ETA: 0:02:46
# Sampling  16%|██████▌                                   |  ETA: 0:02:44
# Sampling  16%|██████▊                                   |  ETA: 0:02:41
# Sampling  16%|██████▉                                   |  ETA: 0:02:42
# Sampling  17%|███████▏                                  |  ETA: 0:02:41
# Sampling  18%|███████▍                                  |  ETA: 0:02:38
# Sampling  18%|███████▌                                  |  ETA: 0:02:36
# Sampling  18%|███████▊                                  |  ETA: 0:02:35
# Sampling  19%|████████                                  |  ETA: 0:02:36
# Sampling  20%|████████▎                                 |  ETA: 0:02:35
# Sampling  20%|████████▍                                 |  ETA: 0:02:33
# Sampling  20%|████████▋                                 |  ETA: 0:02:32
# Sampling  21%|████████▉                                 |  ETA: 0:02:30
# Sampling  22%|█████████                                 |  ETA: 0:02:29
# Sampling  22%|█████████▎                                |  ETA: 0:02:28
# Sampling  22%|█████████▌                                |  ETA: 0:02:26
# Sampling  23%|█████████▋                                |  ETA: 0:02:24
# Sampling  24%|█████████▉                                |  ETA: 0:02:23
# Sampling  24%|██████████▏                               |  ETA: 0:02:22
# Sampling  24%|██████████▎                               |  ETA: 0:02:21
# Sampling  25%|██████████▌                               |  ETA: 0:02:18
# Sampling  26%|██████████▊                               |  ETA: 0:02:16
# Sampling  26%|██████████▉                               |  ETA: 0:02:14
# Sampling  26%|███████████▏                              |  ETA: 0:02:12
# Sampling  27%|███████████▍                              |  ETA: 0:02:10
# Sampling  28%|███████████▌                              |  ETA: 0:02:09
# Sampling  28%|███████████▊                              |  ETA: 0:02:07
# Sampling  28%|████████████                              |  ETA: 0:02:05
# Sampling  29%|████████████▏                             |  ETA: 0:02:03
# Sampling  30%|████████████▍                             |  ETA: 0:02:01
# Sampling  30%|████████████▋                             |  ETA: 0:01:59
# Sampling  30%|████████████▊                             |  ETA: 0:01:58
# Sampling  31%|█████████████                             |  ETA: 0:01:56
# Sampling  32%|█████████████▎                            |  ETA: 0:01:54
# Sampling  32%|█████████████▌                            |  ETA: 0:01:53
# Sampling  32%|█████████████▋                            |  ETA: 0:01:51
# Sampling  33%|█████████████▉                            |  ETA: 0:01:49
# Sampling  34%|██████████████▏                           |  ETA: 0:01:48
# Sampling  34%|██████████████▎                           |  ETA: 0:01:46
# Sampling  34%|██████████████▌                           |  ETA: 0:01:45
# Sampling  35%|██████████████▊                           |  ETA: 0:01:44
# Sampling  36%|██████████████▉                           |  ETA: 0:01:42
# Sampling  36%|███████████████▏                          |  ETA: 0:01:41
# Sampling  36%|███████████████▍                          |  ETA: 0:01:40
# Sampling  37%|███████████████▌                          |  ETA: 0:01:38
# Sampling  38%|███████████████▊                          |  ETA: 0:01:37
# Sampling  38%|████████████████                          |  ETA: 0:01:36
# Sampling  38%|████████████████▏                         |  ETA: 0:01:34
# Sampling  39%|████████████████▍                         |  ETA: 0:01:33
# Sampling  40%|████████████████▋                         |  ETA: 0:01:32
# Sampling  40%|████████████████▊                         |  ETA: 0:01:31
# Sampling  40%|█████████████████                         |  ETA: 0:01:30
# Sampling  41%|█████████████████▎                        |  ETA: 0:01:28
# Sampling  42%|█████████████████▍                        |  ETA: 0:01:27
# Sampling  42%|█████████████████▋                        |  ETA: 0:01:26
# Sampling  42%|█████████████████▉                        |  ETA: 0:01:25
# Sampling  43%|██████████████████                        |  ETA: 0:01:24
# Sampling  44%|██████████████████▎                       |  ETA: 0:01:23
# Sampling  44%|██████████████████▌                       |  ETA: 0:01:22
# Sampling  44%|██████████████████▊                       |  ETA: 0:01:21
# Sampling  45%|██████████████████▉                       |  ETA: 0:01:20
# Sampling  46%|███████████████████▏                      |  ETA: 0:01:19
# Sampling  46%|███████████████████▍                      |  ETA: 0:01:18
# Sampling  46%|███████████████████▌                      |  ETA: 0:01:17
# Sampling  47%|███████████████████▊                      |  ETA: 0:01:16
# Sampling  48%|████████████████████                      |  ETA: 0:01:15
# Sampling  48%|████████████████████▏                     |  ETA: 0:01:14
# Sampling  48%|████████████████████▍                     |  ETA: 0:01:13
# Sampling  49%|████████████████████▋                     |  ETA: 0:01:12
# Sampling  50%|████████████████████▊                     |  ETA: 0:01:11
# Sampling  50%|█████████████████████                     |  ETA: 0:01:10
# Sampling  50%|█████████████████████▎                    |  ETA: 0:01:09
# Sampling  51%|█████████████████████▍                    |  ETA: 0:01:08
# Sampling  52%|█████████████████████▋                    |  ETA: 0:01:07
# Sampling  52%|█████████████████████▉                    |  ETA: 0:01:06
# Sampling  52%|██████████████████████                    |  ETA: 0:01:05
# Sampling  53%|██████████████████████▎                   |  ETA: 0:01:04
# Sampling  54%|██████████████████████▌                   |  ETA: 0:01:03
# Sampling  54%|██████████████████████▋                   |  ETA: 0:01:02
# Sampling  55%|██████████████████████▉                   |  ETA: 0:01:02
# Sampling  55%|███████████████████████▏                  |  ETA: 0:01:01
# Sampling  56%|███████████████████████▎                  |  ETA: 0:01:00
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:59
# Sampling  56%|███████████████████████▊                  |  ETA: 0:00:58
# Sampling  57%|████████████████████████                  |  ETA: 0:00:57
# Sampling  57%|████████████████████████▏                 |  ETA: 0:00:57
# Sampling  58%|████████████████████████▍                 |  ETA: 0:00:56
# Sampling  58%|████████████████████████▋                 |  ETA: 0:00:55
# Sampling  59%|████████████████████████▊                 |  ETA: 0:00:54
# Sampling  60%|█████████████████████████                 |  ETA: 0:00:53
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:53
# Sampling  60%|█████████████████████████▍                |  ETA: 0:00:52
# Sampling  61%|█████████████████████████▋                |  ETA: 0:00:51
# Sampling  62%|█████████████████████████▉                |  ETA: 0:00:50
# Sampling  62%|██████████████████████████                |  ETA: 0:00:50
# Sampling  62%|██████████████████████████▎               |  ETA: 0:00:49
# Sampling  63%|██████████████████████████▌               |  ETA: 0:00:48
# Sampling  64%|██████████████████████████▋               |  ETA: 0:00:47
# Sampling  64%|██████████████████████████▉               |  ETA: 0:00:47
# Sampling  64%|███████████████████████████▏              |  ETA: 0:00:46
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:45
# Sampling  66%|███████████████████████████▌              |  ETA: 0:00:44
# Sampling  66%|███████████████████████████▊              |  ETA: 0:00:44
# Sampling  66%|███████████████████████████▉              |  ETA: 0:00:43
# Sampling  67%|████████████████████████████▏             |  ETA: 0:00:42
# Sampling  68%|████████████████████████████▍             |  ETA: 0:00:41
# Sampling  68%|████████████████████████████▌             |  ETA: 0:00:41
# Sampling  68%|████████████████████████████▊             |  ETA: 0:00:40
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:39
# Sampling  70%|█████████████████████████████▎            |  ETA: 0:00:39
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:38
# Sampling  70%|█████████████████████████████▋            |  ETA: 0:00:37
# Sampling  71%|█████████████████████████████▉            |  ETA: 0:00:36
# Sampling  72%|██████████████████████████████            |  ETA: 0:00:36
# Sampling  72%|██████████████████████████████▎           |  ETA: 0:00:35
# Sampling  72%|██████████████████████████████▌           |  ETA: 0:00:34
# Sampling  73%|██████████████████████████████▋           |  ETA: 0:00:34
# Sampling  74%|██████████████████████████████▉           |  ETA: 0:00:33
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:32
# Sampling  74%|███████████████████████████████▎          |  ETA: 0:00:32
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:31
# Sampling  76%|███████████████████████████████▊          |  ETA: 0:00:30
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:30
# Sampling  76%|████████████████████████████████▏         |  ETA: 0:00:29
# Sampling  77%|████████████████████████████████▍         |  ETA: 0:00:28
# Sampling  78%|████████████████████████████████▌         |  ETA: 0:00:28
# Sampling  78%|████████████████████████████████▊         |  ETA: 0:00:27
# Sampling  78%|█████████████████████████████████         |  ETA: 0:00:26
# Sampling  79%|█████████████████████████████████▏        |  ETA: 0:00:26
# Sampling  80%|█████████████████████████████████▍        |  ETA: 0:00:25
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:24
# Sampling  80%|█████████████████████████████████▊        |  ETA: 0:00:24
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:23
# Sampling  82%|██████████████████████████████████▎       |  ETA: 0:00:23
# Sampling  82%|██████████████████████████████████▌       |  ETA: 0:00:22
# Sampling  82%|██████████████████████████████████▋       |  ETA: 0:00:21
# Sampling  83%|██████████████████████████████████▉       |  ETA: 0:00:21
# Sampling  84%|███████████████████████████████████▏      |  ETA: 0:00:20
# Sampling  84%|███████████████████████████████████▎      |  ETA: 0:00:19
# Sampling  84%|███████████████████████████████████▌      |  ETA: 0:00:19
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:18
# Sampling  86%|███████████████████████████████████▉      |  ETA: 0:00:17
# Sampling  86%|████████████████████████████████████▏     |  ETA: 0:00:17
# Sampling  86%|████████████████████████████████████▍     |  ETA: 0:00:16
# Sampling  87%|████████████████████████████████████▌     |  ETA: 0:00:16
# Sampling  88%|████████████████████████████████████▊     |  ETA: 0:00:15
# Sampling  88%|█████████████████████████████████████     |  ETA: 0:00:14
# Sampling  88%|█████████████████████████████████████▏    |  ETA: 0:00:14
# Sampling  89%|█████████████████████████████████████▍    |  ETA: 0:00:13
# Sampling  90%|█████████████████████████████████████▋    |  ETA: 0:00:13
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:12
# Sampling  90%|██████████████████████████████████████    |  ETA: 0:00:11
# Sampling  91%|██████████████████████████████████████▎   |  ETA: 0:00:11
# Sampling  92%|██████████████████████████████████████▍   |  ETA: 0:00:10
# Sampling  92%|██████████████████████████████████████▋   |  ETA: 0:00:09
# Sampling  92%|██████████████████████████████████████▉   |  ETA: 0:00:09
# Sampling  93%|███████████████████████████████████████   |  ETA: 0:00:08
# Sampling  94%|███████████████████████████████████████▎  |  ETA: 0:00:08
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:07
# Sampling  94%|███████████████████████████████████████▊  |  ETA: 0:00:06
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:06
# Sampling  96%|████████████████████████████████████████▏ |  ETA: 0:00:05
# Sampling  96%|████████████████████████████████████████▍ |  ETA: 0:00:05
# Sampling  96%|████████████████████████████████████████▌ |  ETA: 0:00:04
# Sampling  97%|████████████████████████████████████████▊ |  ETA: 0:00:04
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:03
# Sampling  98%|█████████████████████████████████████████▏|  ETA: 0:00:02
# Sampling  98%|█████████████████████████████████████████▍|  ETA: 0:00:02
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:01
# Sampling 100%|█████████████████████████████████████████▊|  ETA: 0:00:01
# Sampling 100%|██████████████████████████████████████████| Time: 0:01:56
# Sampling 100%|██████████████████████████████████████████| Time: 0:01:56
# Chains MCMC chain (3000×57×1 Array{Float64, 3}):
#
# Iterations        = 1001:1:4000
# Number of chains  = 1
# Samples per chain = 3000
# Wall duration     = 116.83 seconds
# Compute duration  = 116.83 seconds
# parameters        = μatt, μdef, σatt, σdef, home, att[1], def[1], att[2], def[2], att[3], def[3], att[4], def[4], att[5], def[5], att[6], def[6], att[7], def[7], att[8], def[8], att[9], def[9], att[10], def[10], att[11], def[11], att[12], def[12], att[13], def[13], att[14], def[14], att[15], def[15], att[16], def[16], att[17], def[17], att[18], def[18], att[19], def[19], att[20], def[20]
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std      mcse    ess_bulk    ess_tail      rhat   ⋯
#       Symbol   Float64   Float64   Float64     Float64     Float64   Float64   ⋯
#
#         μatt   -0.0085    0.0984    0.0050    391.5426    928.8448    1.0049   ⋯
#         μdef    0.0012    0.1011    0.0058    298.5973    599.5608    1.0027   ⋯
#         σatt    0.3827    0.0783    0.0016   2511.1046   2208.5496    1.0008   ⋯
#         σdef    0.2182    0.0587    0.0020    795.0066    662.5786    1.0002   ⋯
#         home    0.3374    0.0437    0.0008   3019.3601   2102.6675    0.9997   ⋯
#       att[1]   -0.2703    0.1981    0.0084    558.5292    896.0776    1.0012   ⋯
#       def[1]   -0.1717    0.1639    0.0071    534.2159    997.9341    1.0012   ⋯
#       att[2]   -0.0708    0.1859    0.0080    535.3931    995.9037    1.0022   ⋯
#       def[2]    0.0633    0.1608    0.0076    452.2616    738.9697    1.0020   ⋯
#       att[3]   -0.4544    0.2020    0.0084    582.8301   1200.3510    1.0024   ⋯
#       def[3]    0.0926    0.1580    0.0076    426.4647    717.1200    1.0005   ⋯
#       att[4]    0.5034    0.1718    0.0087    387.9562    859.7492    1.0035   ⋯
#       def[4]   -0.1575    0.1690    0.0072    557.9985   1166.9129    1.0018   ⋯
#       att[5]    0.2904    0.1776    0.0081    475.0121    832.2082    1.0041   ⋯
#       def[5]   -0.3351    0.1841    0.0073    634.4018   1265.3213    1.0037   ⋯
#       att[6]   -0.1981    0.1967    0.0081    592.0905   1290.8748    1.0029   ⋯
#       def[6]   -0.0507    0.1623    0.0074    482.5426   1148.6050    1.0008   ⋯
#       ⋮           ⋮         ⋮         ⋮          ⋮           ⋮          ⋮      ⋱
#                                                     1 column and 28 rows omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#         μatt   -0.2011   -0.0749   -0.0103    0.0566    0.1906
#         μdef   -0.1896   -0.0684    0.0024    0.0684    0.2019
#         σatt    0.2619    0.3279    0.3722    0.4259    0.5666
#         σdef    0.1195    0.1783    0.2137    0.2534    0.3438
#         home    0.2496    0.3085    0.3377    0.3668    0.4239
#       att[1]   -0.6687   -0.4039   -0.2693   -0.1364    0.1078
#       def[1]   -0.5020   -0.2769   -0.1680   -0.0646    0.1478
#       att[2]   -0.4412   -0.1975   -0.0719    0.0552    0.2853
#       def[2]   -0.2474   -0.0472    0.0616    0.1697    0.3862
#       att[3]   -0.8699   -0.5854   -0.4486   -0.3124   -0.0799
#       def[3]   -0.2212   -0.0131    0.0909    0.1977    0.4064
#       att[4]    0.1585    0.3882    0.5019    0.6170    0.8310
#       def[4]   -0.5006   -0.2690   -0.1584   -0.0472    0.1688
#       att[5]   -0.0546    0.1719    0.2857    0.4111    0.6416
#       def[5]   -0.7061   -0.4533   -0.3298   -0.2076    0.0100
#       att[6]   -0.5769   -0.3261   -0.1958   -0.0653    0.1716
#       def[6]   -0.3748   -0.1593   -0.0539    0.0630    0.2598
#       ⋮           ⋮         ⋮         ⋮         ⋮         ⋮
#                                                  28 rows omitted

# %%
posterior_df=DataFrame(posterior)
# Out:
# 3000×59 DataFrame
#   Row │ iteration  chain  μatt         μdef         σatt      σdef      home   ⋯
#       │ Int64      Int64  Float64      Float64      Float64   Float64   Float6 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │      1001      1   0.212123     0.0721608   0.439475  0.260719  0.3704 ⋯
#     2 │      1002      1   0.120683     0.0593745   0.511534  0.256607  0.3633
#     3 │      1003      1   0.00669415   0.00149332  0.286996  0.258267  0.2882
#     4 │      1004      1  -0.0761406   -0.0792776   0.349943  0.250393  0.3324
#     5 │      1005      1  -0.0276157   -0.076841    0.311368  0.274725  0.3355 ⋯
#     6 │      1006      1   0.0652886   -0.123605    0.546236  0.149502  0.3132
#     7 │      1007      1   0.00548126  -0.0194196   0.339458  0.216598  0.3756
#     8 │      1008      1  -0.0308591    0.090857    0.389423  0.203028  0.2772
#   ⋮   │     ⋮        ⋮         ⋮            ⋮          ⋮         ⋮         ⋮   ⋱
#  2994 │      3994      1   0.120128     0.0264607   0.392966  0.138756  0.2926 ⋯
#  2995 │      3995      1   0.132766     0.0348499   0.370724  0.174904  0.3115
#  2996 │      3996      1  -0.050738    -0.0416424   0.359184  0.17118   0.3321
#  2997 │      3997      1  -0.0405142   -0.00920097  0.342185  0.211554  0.3414
#  2998 │      3998      1   0.124532     0.0432995   0.445868  0.341726  0.3268 ⋯
#  2999 │      3999      1  -0.0389678    0.104613    0.320629  0.201918  0.3266
#  3000 │      4000      1  -0.073942     0.195159    0.348366  0.179143  0.2940
#                                                 53 columns and 2985 rows omitted

# %%
DataFrames.transform!(posterior_df, AsTable(Between("att[1]","att[20]")) => ByRow(mean) => :att_mean)
DataFrames.transform!(posterior_df, AsTable(Between("def[1]","def[20]")) => ByRow(mean) => :def_mean)
DataFrames.transform!(posterior_df, AsTable([:att_mean,:def_mean]) => ByRow(sum) => :offset)
# Out:
# 3000×62 DataFrame
#   Row │ iteration  chain  μatt         μdef         σatt      σdef      home   ⋯
#       │ Int64      Int64  Float64      Float64      Float64   Float64   Float6 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │      1001      1   0.212123     0.0721608   0.439475  0.260719  0.3704 ⋯
#     2 │      1002      1   0.120683     0.0593745   0.511534  0.256607  0.3633
#     3 │      1003      1   0.00669415   0.00149332  0.286996  0.258267  0.2882
#     4 │      1004      1  -0.0761406   -0.0792776   0.349943  0.250393  0.3324
#     5 │      1005      1  -0.0276157   -0.076841    0.311368  0.274725  0.3355 ⋯
#     6 │      1006      1   0.0652886   -0.123605    0.546236  0.149502  0.3132
#     7 │      1007      1   0.00548126  -0.0194196   0.339458  0.216598  0.3756
#     8 │      1008      1  -0.0308591    0.090857    0.389423  0.203028  0.2772
#   ⋮   │     ⋮        ⋮         ⋮            ⋮          ⋮         ⋮         ⋮   ⋱
#  2994 │      3994      1   0.120128     0.0264607   0.392966  0.138756  0.2926 ⋯
#  2995 │      3995      1   0.132766     0.0348499   0.370724  0.174904  0.3115
#  2996 │      3996      1  -0.050738    -0.0416424   0.359184  0.17118   0.3321
#  2997 │      3997      1  -0.0405142   -0.00920097  0.342185  0.211554  0.3414
#  2998 │      3998      1   0.124532     0.0432995   0.445868  0.341726  0.3268 ⋯
#  2999 │      3999      1  -0.0389678    0.104613    0.320629  0.201918  0.3266
#  3000 │      4000      1  -0.073942     0.195159    0.348366  0.179143  0.2940
#                                                 56 columns and 2985 rows omitted

# %%
# For this example, we are interested in a pair of teams (no need to use map for all teams)

teamA = "Manchester City"
teamB = "Manchester United"

teamA_id = findfirst(isequal(teamA), teams)
teamB_id = findfirst(isequal(teamB), teams)
print("teamA id", teamA_id)
print("teamB id",teamB_id)

teamA_att_post = posterior_df[:,"att[$teamA_id]"]
teamA_def_post = posterior_df[:,"def[$teamA_id]"]

teamB_att_post = posterior_df[:,"att[$teamB_id]"]
teamB_def_post = posterior_df[:,"def[$teamB_id]"]
# Out:
# teamA id11teamB id5
# 3000-element Vector{Float64}:
#  -0.3814997655145913
#  -0.11231795576851922
#  -0.6614933039424077
#  -0.3844359919631573
#  -0.3452963395182882
#  -0.3407526902488991
#  -0.3840357584794904
#  -0.2282961505403543
#  -0.07621529458718362
#  -0.5177942252824868
#   ⋮
#  -0.3347077360102696
#  -0.16622453187398936
#  -0.26092277630680977
#  -0.05204494671733195
#  -0.42784423811750827
#  -0.21840784382936357
#  -0.46381074729453514
#  -0.2044122349357073
#  -0.16258176444336508

# %%
ha1 = histogram(teamA_att_post, title=teamA*" attack", titlefontsize = 12, legend=false, normalized=true);
ha2 = histogram(teamB_att_post, title=teamB*" attack", titlefontsize = 12, legend=false, normalized=true);
plot(ha1, ha2, layout=(1,2));
xlabel!("Attack power");
ylabel!("Probability density")

# %%
hd1 = histogram(teamA_def_post, title=teamA*" defense", titlefontsize = 12, legend=false, normalized=true);
hd2 = histogram(teamB_def_post, title=teamB*" defense", titlefontsize = 12, legend=false, normalized=true);
plot(hd1, hd2, layout=(1,2));
xlabel!("Defense power");
ylabel!("Probability density")

# %%
hd1 = histogram(posterior_df[:,"μatt"], title= "mean attack", titlefontsize = 12, legend=false, normalized=true);
hd2 = histogram(posterior_df[:,"μdef"], title= "mean defense", titlefontsize = 12, legend=false, normalized=true);
plot(hd1, hd2, layout=(1,2));
xlabel!("power");
ylabel!("Probability density")

# %% [markdown]
# ### Mini Project
#
# Consult the lecture notes.

# %%
Random.seed!(1234)
# hint: let's simulate 500 hypothetical finals (then you will have a total of 3000*500 samples)

# first leg: teamA is the home team and teamB is the away team

θ_home = posterior_df[:,:home] + posterior_df[:,"att[$teamA_id]"] + posterior_df[:,"def[$teamB_id]"] - posterior_df[:,:offset]
θ_away = posterior_df[:, "att[$teamB_id]"] + posterior_df[:, "def[$teamA_id]"] - posterior_df[:,:offset]

teamA_score = rand.(Poisson.(exp.(θ_home)),500)
teamB_score = rand.(Poisson.(exp.(θ_away)),500)

# second leg: teamA is the away team and teamB is the home team

θ_home = posterior_df[:,:home] + posterior_df[:,"att[$teamB_id]"] + posterior_df[:,"def[$teamA_id]"] - posterior_df[:,:offset]
θ_away = posterior_df[:, "att[$teamA_id]"] + posterior_df[:, "def[$teamB_id]"] - posterior_df[:,:offset]

teamA_score += rand.(Poisson.(exp.(θ_away)),500)  # add the first-leg result with the second-leg result
teamB_score += rand.(Poisson.(exp.(θ_home)),500)

# transform into long column vectors
teamA_score = vcat(teamA_score...)
teamB_score = vcat(teamB_score...)
# Out:
# 1500000-element Vector{Int64}:
#  0
#  4
#  3
#  1
#  6
#  2
#  2
#  4
#  1
#  0
#  ⋮
#  5
#  3
#  3
#  4
#  2
#  4
#  2
#  2
#  3

# %%
# Visualize the normalized score distribution for 2 teams
x_bins = 0:1:maximum(teamA_score)
y_bins = 0:1:maximum(teamB_score)
histogram2d(teamA_score, 
            teamB_score, 
            fill = true,
            bins = (x_bins, y_bins),
            normalize=:pdf
            )
title!("Simulated 2-leg football game scores (normalized)")
xlabel!("Team A $teamA score")
ylabel!("Team B $teamB score")

# %%
savefig("heatmap_norm.png")
# Out:
# "/Users/xinwenliu/Documents/Classes/ucla/Bayesian_statistics/codes/STJuliaIntroBayesian-main/heatmap_norm.png"

# %%
# Calculate the inferred winning ability of each game
# Number of total simulations
n = length(teamA_score)

# Probability Team A wins (aggregate score strictly higher)
p_teamA_win = sum(teamA_score .> teamB_score) / n

# Probability Team B wins (aggregate score strictly higher)
p_teamB_win = sum(teamB_score .> teamA_score) / n

# (Optional) Probability of an exact tie in aggregate
p_tie = sum(teamA_score .== teamB_score) / n

println("Team A $teamA win probability: $p_teamA_win")
println("Team B $teamB win probability: $p_teamB_win")
println("Tie probability: $p_tie")
# Out:
# Team A Manchester City win probability: 0.6144626666666667
# Team B Manchester United win probability: 0.2404
# Tie probability: 0.14513733333333334
